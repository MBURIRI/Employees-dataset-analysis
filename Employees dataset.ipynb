# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib import style

# %%
df=pd.read_csv(r"E:\data analysis using python( jupytetr notebooks)\Lawrence Mbura\Employee.csv",index_col='EmployeeID')
pd.set_option('display.max.columns',23)
df
# Out:
#              FirstName     LastName      Gender  Age BusinessTravel  \
# EmployeeID
# 3012-1A41     Leonelle        Simco      Female   30    Some Travel
# CBCB-9C9D      Leonerd        Aland        Male   38    Some Travel
# 95D7-1CE9        Ahmed        Sykes        Male   43    Some Travel
# 47A0-559B   Ermentrude       Berrie  Non-Binary   39    Some Travel
# 42CC-040A        Stace       Savege      Female   29    Some Travel
# ...                ...          ...         ...  ...            ...
# 467E-977A          Jud    Melanaphy        Male   20    Some Travel
# 6FB9-A624         Marc       Calver  Non-Binary   27    Some Travel
# EBF4-5928      Rudolph  MacDearmont        Male   21    Some Travel
# 60E6-B1D9       Merill          Agg        Male   21    Some Travel
# 84D4-D4C3        Naoma      Hebbard      Female   20     No Travel
#
#                  Department  DistanceFromHome (KM) State  \
# EmployeeID
# 3012-1A41             Sales                     27    IL
# ...

# %%
df.drop_duplicates()
# Out:
#      EmployeeID   FirstName     LastName      Gender  Age BusinessTravel  \
# 0     3012-1A41    Leonelle        Simco      Female   30    Some Travel
# 1     CBCB-9C9D     Leonerd        Aland        Male   38    Some Travel
# 2     95D7-1CE9       Ahmed        Sykes        Male   43    Some Travel
# 3     47A0-559B  Ermentrude       Berrie  Non-Binary   39    Some Travel
# 4     42CC-040A       Stace       Savege      Female   29    Some Travel
# ...         ...         ...          ...         ...  ...            ...
# 1465  467E-977A         Jud    Melanaphy        Male   20    Some Travel
# 1466  6FB9-A624        Marc       Calver  Non-Binary   27    Some Travel
# 1467  EBF4-5928     Rudolph  MacDearmont        Male   21    Some Travel
# 1468  60E6-B1D9      Merill          Agg        Male   21    Some Travel
# 1469  84D4-D4C3       Naoma      Hebbard      Female   20     No Travel
#
#            Department  DistanceFromHome (KM) State                  Ethnicity  \
# ...

# %%
df.isnull().sum()
# Out:
# EmployeeID                 0
# FirstName                  0
# LastName                   0
# Gender                     0
# Age                        0
# BusinessTravel             0
# Department                 0
# DistanceFromHome (KM)      0
# State                      0
# Ethnicity                  0
# Education                  0
# EducationField             0
# JobRole                    0
# MaritalStatus              0
# Salary                     0
# StockOptionLevel           0
# OverTime                   0
# HireDate                   0
# Attrition                  0
# YearsAtCompany             0
# YearsInMostRecentRole      0
# YearsSinceLastPromotion    0
# YearsWithCurrManager       0
# dtype: int64

# %%
df.shape
# Out:
# (1470, 23)

# %%
df.columns
# Out:
# Index(['EmployeeID', 'FirstName', 'LastName', 'Gender', 'Age',
#        'BusinessTravel', 'Department', 'DistanceFromHome (KM)', 'State',
#        'Ethnicity', 'Education', 'EducationField', 'JobRole', 'MaritalStatus',
#        'Salary', 'StockOptionLevel', 'OverTime', 'HireDate', 'Attrition',
#        'YearsAtCompany', 'YearsInMostRecentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
df.head()
# Out:
#              FirstName LastName      Gender  Age BusinessTravel  \
# EmployeeID
# 3012-1A41     Leonelle    Simco      Female   30    Some Travel
# CBCB-9C9D      Leonerd    Aland        Male   38    Some Travel
# 95D7-1CE9        Ahmed    Sykes        Male   43    Some Travel
# 47A0-559B   Ermentrude   Berrie  Non-Binary   39    Some Travel
# 42CC-040A        Stace   Savege      Female   29    Some Travel
#
#                  Department  DistanceFromHome (KM) State  \
# EmployeeID
# 3012-1A41             Sales                     27    IL
# CBCB-9C9D             Sales                     23    CA
# 95D7-1CE9   Human Resources                     29    CA
# 47A0-559B        Technology                     12    IL
# 42CC-040A   Human Resources                     29    CA
#
#                           Ethnicity  Education    EducationField  \
# EmployeeID
# 3012-1A41                     White          5         Marketing
# ...

# %% [markdown]
# ### How many job roles are in the firm?

# %%
df['JobRole'].value_counts()
# Out:
# JobRole
# Sales Executive              327
# Software Engineer            294
# Data Scientist               261
# Machine Learning Engineer    146
# Senior Software Engineer     132
# Sales Representative          83
# Engineering Manager           75
# Analytics Manager             52
# Manager                       37
# HR Executive                  28
# Recruiter                     24
# HR Business Partner            7
# HR Manager                     4
# Name: count, dtype: int64

# %% [markdown]
# ### Group the departments according to their ethnicity

# %%
df.groupby('Department')['Ethnicity'].value_counts()
# Out:
# Department       Ethnicity
# Human Resources  White                                30
#                  Mixed or multiple ethnic groups      12
#                  Black or African American            10
#                  Asian or Asian American               5
#                  American Indian or Alaska Native      2
#                  Native Hawaiian                       2
#                  Other                                 2
# Sales            White                               262
#                  Mixed or multiple ethnic groups      66
#                  Black or African American            55
#                  Asian or Asian American              36
#                  American Indian or Alaska Native     14
#                  Native Hawaiian                       7
#                  Other                                 6
# Technology       White                               568
#                  Black or African American           142
# ...

# %% [markdown]
# ### Group gender based on their marital status

# %%
df.groupby('Gender')['MaritalStatus'].value_counts()
# Out:
# Gender             MaritalStatus
# Female             Married          288
#                    Single           251
#                    Divorced         136
# Male               Married          282
#                    Single           231
#                    Divorced         138
# Non-Binary         Single            60
#                    Married           46
#                    Divorced          18
# Prefer Not To Say  Married            8
#                    Single             7
#                    Divorced           5
# Name: count, dtype: int64

# %% [markdown]
# ### Number for 'stockoptionlevel'

# %%
count=df['StockOptionLevel'].value_counts()
count
# Out:
# StockOptionLevel
# 0    631
# 1    596
# 2    158
# 3     85
# Name: count, dtype: int64

# %%
plt.pie(count,labels=count.index,autopct='%.2f%%')
plt.legend(loc='upper left')

# %%
count_1=df['MaritalStatus'].value_counts()
count_1
# Out:
# MaritalStatus
# Married     624
# Single      549
# Divorced    297
# Name: count, dtype: int64

# %%
plt.pie(count_1, autopct='%.2f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x29886e8f830>,
# ...
#  [Text(0.2585039582380671, 1.0691939504015404, ''),
#   Text(-0.8421446627281534, -0.7076668474914484, ''),
#   Text(0.8857552114774572, -0.6522558588012265, '')],
#  [Text(0.14100215903894567, 0.583196700219022, '42.45%'),
#   Text(-0.4593516342153563, -0.38600009863169904, '37.35%'),
#   Text(0.4831392062604311, -0.3557759229824871, '20.20%')])

# %% [markdown]
# ### How many workers prefer Attrition

# %%
df.groupby('Attrition').get_group('Yes')
# Out:
#            FirstName   LastName  Gender  Age      BusinessTravel  \
# EmployeeID
# 42CC-040A      Stace     Savege  Female   29         Some Travel
# 5476-CA0D     Kayley      Snoad  Female   31  Frequent Traveller
# D7EE-56FC    Zsa zsa     Evered  Female   39  Frequent Traveller
# 00D4-DD53      Joyce       Goor  Female   30  Frequent Traveller
# 3CD6-5587     Dorise    Klishin  Female   31         Some Travel
# ...              ...        ...     ...  ...                 ...
# 3E4A-F28F       Rubi   Hawkwood  Female   20         Some Travel
# 1CB3-F7D7      Janot  Cicchillo  Female   21          No Travel
# B005-602F     Layney      Ratie  Female   19         Some Travel
# 45F9-3A37     Talbot   Sturgess    Male   21         Some Travel
# 06E8-4FD4     Emilee     Wenham  Female   20         Some Travel
#
#                  Department  DistanceFromHome (KM) State  \
# EmployeeID
# 42CC-040A   Human Resources                     29    CA
# ...
